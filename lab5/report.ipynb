# %% [markdown]
# # Лабораторная работа №5
# ## Моделирование сети массового обслуживания
#
# **Тема:** Оптимизация системы с ограниченной очередью (банковское обслуживание "одно окошко")
#
# ### Описание модели
#
# #### Параметры сети
# - **Входящий поток заявок (λ)**: 10 заявок/час
# - **Интенсивность обслуживания (μ)**: 3 заявки/час
# - **Максимальное число агентов**: 5
# - **Минимальное число агентов**: 1
# - **Время моделирования**: 1000 часов
#
# #### Алгоритм работы агентов
# 1. Агенты динамически подключаются и отключаются во времени.
# 2. Если агент подключается, увеличивается количество доступных серверов.
# 3. Если агент отключается, уменьшается количество серверов.
# 4. Если все серверы заняты, заявки попадают в очередь.
# 5. Если заявка ждёт слишком долго, она теряется.
#
# ---
#
# ## 📊 **Реализация модели в Python**

# %%
from lab5.lab.result import print_res, show_plot

# %%
print_res()
# Out:
# Среднее время ожидания: 0.37
# Средняя длина очереди: 0.83
# Среднее число агентов: 4.48
# Вероятность потери заявки: 72.45%

# %% [markdown]
# ## 📈 **Результаты экспериментов**
# ### Таблицы данных
#
# | Показатель | Значение |
# |------------|----------|
# | Среднее время ожидания | `0.37`   |
# | Средняя длина очереди | `0.83`   |
# | Среднее число активных агентов | `4.48`   |
# | Вероятность потери заявок | `72.45%` |
#
# ---
#
# ## 📊 **Графики**

# %%
show_plot()

# %% [markdown]
# ## 📌 **Анализ результатов**
# 1. Среднее время ожидания **0.37** показывает, что при малом числе агентов очередь растёт.
# 2. При увеличении числа агентов до 5 среднее время ожидания падает.
# 3. Длина очереди увеличивается, если агентов меньше 3.
# 4. Вероятность потерь **72.45%** свидетельствует о нехватке агентов в некоторые моменты времени.
#
# ### **Рекомендации по оптимизации**
# - Увеличить минимальное число агентов до 2.
# - Изменить интенсивность входящего потока или балансировать интервал подключения агентов.
# - Уменьшить вероятность отключения агентов.
#
# ---
